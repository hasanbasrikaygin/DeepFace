# %%
import cv2

# %%
img = cv2.imread('happyboy.jpg')

# %%
from deepface import DeepFace # pip install deepface

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #BGR blue green red

# %%
plt.imshow(cv2.cvtColor(img , cv2.COLOR_BGR2RGB))

# %%
predictions= DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  4.30it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 3.325916798913031e-10,
#   'disgust': 2.250897336763205e-20,
#   'fear': 1.2084768612731853e-14,
#   'happy': 99.99997615814209,
#   'sad': 7.879034745602795e-12,
#   'surprise': 1.4640944706600934e-09,
#   'neutral': 2.5729843855515355e-05},
#  'dominant_emotion': 'happy',
#  'region': {'x': 116, 'y': 21, 'w': 215, 'h': 215},
#  'age': 18,
#  'gender': 'Man',
#  'race': {'asian': 16.282163040766896,
#   'indian': 0.19171462605682768,
#   'black': 0.07486057448301163,
#   'white': 69.31766684756677,
#   'middle eastern': 3.507963032005014,
#   'latino hispanic': 10.625632740594908},
#  'dominant_race': 'white'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

#draw a rectangle arond the face
for(x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img , cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

#use putText()  method for
#inserting text on video
cv2.putText(img,
           predictions['dominant_emotion'],
           (0,50),
           font, 1,
           (0, 0, 255),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img , cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sad.png')

# %%
plt.imshow(cv2.cvtColor(img , cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  4.12it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 16.58567041158676,
#   'disgust': 0.08625923073850572,
#   'fear': 6.765797734260559,
#   'happy': 0.01501669903518632,
#   'sad': 67.21586585044861,
#   'surprise': 0.1388021744787693,
#   'neutral': 9.192585945129395},
#  'dominant_emotion': 'sad',
#  'region': {'x': 207, 'y': 108, 'w': 218, 'h': 218},
#  'age': 30,
#  'gender': 'Man',
#  'race': {'asian': 0.006700630582720374,
#   'indian': 4.460243029012861,
#   'black': 0.0071816761834800945,
#   'white': 10.457263020113887,
#   'middle eastern': 79.74151848206034,
#   'latino hispanic': 5.327095036333503},
#  'dominant_race': 'middle eastern'}
